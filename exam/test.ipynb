# %%
# task1 
# Function to find the number is odd or even. 

i = 10
print(i)
# Out:
# 10

# %% [markdown]
# # Suridh K.C.
#
# ## University id: c7683898

# %%
### Hello how are you doing ? i am using VS code to code and i am learning python right now and learning how to use jupiternotebook and how to push it in github.
